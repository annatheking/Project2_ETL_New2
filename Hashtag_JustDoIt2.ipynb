# %%
import pandas as pd
import numpy as np
from dateutil.parser import parse
import json
import pprint
from bs4 import BeautifulSoup
import requests

# %%
################ Source One ###################
## Kaggle #JustDoIt data

#import csv file to pandas
#==============================================

data = pd.read_csv('justdoit_tweets_2018_09_07_2.csv/justdoit_tweets_2018_09_07_2.csv')
#data["tweet_full_text"]
data.head()
# Out:
#    tweet_contributors                                  tweet_coordinates  \
# 0                 NaN                                                NaN
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                 NaN  {'type': 'Point', 'coordinates': [-86.45594032...
# 4                 NaN                                                NaN
#
#                  tweet_created_at tweet_display_text_range  \
# 0  Fri Sep 07 16:25:06 +0000 2018                  [0, 75]
# 1  Fri Sep 07 16:24:59 +0000 2018                 [0, 237]
# 2  Fri Sep 07 16:24:50 +0000 2018                 [0, 176]
# 3  Fri Sep 07 16:24:44 +0000 2018                  [0, 88]
# 4  Fri Sep 07 16:24:39 +0000 2018                 [0, 132]
#
#                                       tweet_entities  \
# 0  {'hashtags': [{'text': 'quote', 'indices': [47...
# 1  {'hashtags': [{'text': 'hero', 'indices': [90,...
# 2  {'hashtags': [{'text': 'JustDoIt', 'indices': ...
# 3  {'hashtags': [{'text': 'kapernickeffect', 'ind...
# 4  {'hashtags': [{'text': 'shaquem', 'indices': [...
#
#                              tweet_extended_entities  tweet_favorite_count  \
# 0  {'media': [{'id': 1038100853872197632, 'id_str...                     0
# 1                                                NaN                     0
# 2  {'media': [{'id': 1038100773396041728, 'id_str...                     0
# 3                                                NaN                     0
# 4  {'media': [{'id': 1038100736595255296, 'id_str...                     0
#
#    tweet_favorited                                    tweet_full_text  \
# 0            False  Done is better than perfect. — Sheryl Sandberg...
# 1            False  Shout out to the Great Fire Department and the...
# 2            False  There are some AMAZINGLY hilarious Nike Ad mem...
# 3            False  #kapernickeffect #swoosh #justdoit @ Lucas Bis...
# 4            False  One Hand, One Dream: The Shaquem Griffin Story...
#
#                                            tweet_geo      ...       \
# 0                                                NaN      ...
# 1                                                NaN      ...
# 2                                                NaN      ...
# 3  {'type': 'Point', 'coordinates': [35.85402047,...      ...
# 4                                                NaN      ...
#
#    user_profile_text_color  user_profile_use_background_image user_protected  \
# 0                   333333                               True          False
# 1                   333333                               True          False
# 2                    50505                               True          False
# 3                   333333                               True          False
# 4                   1A1E1A                               True          False
#
#    user_screen_name  user_statuses_count  user_time_zone  \
# 0     UltraYOUwoman              91870.0             NaN
# 1         yungcutup             618822.0             NaN
# 2       rachelbogle              48075.0             NaN
# 3       ErvGotti609               1983.0             NaN
# 4      NoLuckNeeded              24989.0             NaN
#
#    user_translator_type                 user_url user_utc_offset user_verified
# 0                  none  https://t.co/jGlJswxjwS             NaN         False
# 1                  none   http://t.co/lVm8vfDbfO             NaN         False
# 2                  none  https://t.co/g9exqgZp9x             NaN          True
# 3                  none                      NaN             NaN         False
# 4                  none   http://t.co/MMGF9RfLz0             NaN         False
#
# [5 rows x 72 columns]

# %%
# Check available variables
#==============================================

list(data)

#Note: 'tweet_' vaiables are tweet related, and 'user_' variables are user related
# Out:
# ['tweet_contributors',
#  'tweet_coordinates',
#  'tweet_created_at',
#  'tweet_display_text_range',
#  'tweet_entities',
#  'tweet_extended_entities',
#  'tweet_favorite_count',
#  'tweet_favorited',
#  'tweet_full_text',
#  'tweet_geo',
#  'tweet_id',
#  'tweet_id_str',
#  'tweet_in_reply_to_screen_name',
#  'tweet_in_reply_to_status_id',
#  'tweet_in_reply_to_status_id_str',
#  'tweet_in_reply_to_user_id',
#  'tweet_in_reply_to_user_id_str',
#  'tweet_is_quote_status',
#  'tweet_lang',
#  'tweet_metadata',
#  'tweet_place',
#  'tweet_possibly_sensitive',
#  'tweet_quoted_status',
#  'tweet_quoted_status_id',
#  'tweet_quoted_status_id_str',
#  'tweet_retweet_count',
#  'tweet_retweeted',
#  'tweet_source',
#  'tweet_truncated',
#  'tweet_user',
#  'user_contributors_enabled',
#  'user_created_at',
#  'user_default_profile',
#  'user_default_profile_image',
#  'user_description',
#  'user_entities',
#  'user_favourites_count',
#  'user_follow_request_sent',
#  'user_followers_count',
#  'user_following',
#  'user_friends_count',
#  'user_geo_enabled',
#  'user_has_extended_profile',
#  'user_id',
#  'user_id_str',
#  'user_is_translation_enabled',
#  'user_is_translator',
#  'user_lang',
#  'user_listed_count',
#  'user_location',
#  'user_name',
#  'user_notifications',
#  'user_profile_background_color',
#  'user_profile_background_image_url',
#  'user_profile_background_image_url_https',
#  'user_profile_background_tile',
#  'user_profile_banner_url',
#  'user_profile_image_url',
#  'user_profile_image_url_https',
#  'user_profile_link_color',
#  'user_profile_sidebar_border_color',
#  'user_profile_sidebar_fill_color',
#  'user_profile_text_color',
#  'user_profile_use_background_image',
#  'user_protected',
#  'user_screen_name',
#  'user_statuses_count',
#  'user_time_zone',
#  'user_translator_type',
#  'user_url',
#  'user_utc_offset',
#  'user_verified']

# %%
#Split 'tweet_' and 'user_' data into to datasets
#Keep only variable we need/want
#==============================================

tweet_data = data[[
 'tweet_created_at',
 'tweet_entities',
 'tweet_extended_entities',
 'tweet_favorite_count',
 'tweet_favorited',
 'tweet_full_text',
 'tweet_lang',
 'tweet_metadata',
 'tweet_possibly_sensitive',
 'tweet_retweet_count',
 'tweet_retweeted',
 'tweet_source',
 'tweet_truncated',
 'tweet_user'
 ]]

tweet_data.head()

user_data = data[[
 'user_created_at',
 'user_id',
 'user_lang',
 'user_location',
 'user_screen_name'
]]

user_data.head()
# Out:
#                   user_created_at       user_id user_lang  \
# 0  Fri May 08 10:27:51 +0000 2015  3.188619e+09        en
# 1  Fri Dec 26 09:30:23 +0000 2008  1.838717e+07        en
# 2  Fri Apr 17 23:04:15 +0000 2009  3.264561e+07        en
# 3  Sun Aug 08 02:02:56 +0000 2010  1.759327e+08        en
# 4  Sat Feb 28 23:13:57 +0000 2009  2.230663e+07        en
#
#                     user_location user_screen_name
# 0                 California, USA    UltraYOUwoman
# 1                  Miami, Florida        yungcutup
# 2                Indianapolis, IN      rachelbogle
# 3  Tennessee by way of New Jersey      ErvGotti609
# 4                     Gambleville     NoLuckNeeded

# %%
#Convert numeric user_id to string
#==============================================

user_data['user_id2'] = user_data['user_id'].apply(lambda x: '%.f' % x).values.tolist()
user_data = user_data.drop(['user_id'], axis=1)
user_data['user_id'] = user_data['user_id2']
user_data = user_data.drop(['user_id2'], axis=1)
# Out:
# C:\Users\shuashua\Anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
user_data.head()
# Out:
#                   user_created_at user_lang                   user_location  \
# 0  Fri May 08 10:27:51 +0000 2015        en                 California, USA
# 1  Fri Dec 26 09:30:23 +0000 2008        en                  Miami, Florida
# 2  Fri Apr 17 23:04:15 +0000 2009        en                Indianapolis, IN
# 3  Sun Aug 08 02:02:56 +0000 2010        en  Tennessee by way of New Jersey
# 4  Sat Feb 28 23:13:57 +0000 2009        en                     Gambleville
#
#   user_screen_name     user_id
# 0    UltraYOUwoman  3188618684
# 1        yungcutup    18387174
# 2      rachelbogle    32645612
# 3      ErvGotti609   175932740
# 4     NoLuckNeeded    22306628

# %%
#Clean user data
#==============================================

#1. Separate date and time
split_datetime = user_data['user_created_at'].str.split()

#2. Create time and create date columns
time_created = []
date_created = []

for x in split_datetime:
    time_created.append(x[3])
    dt = x[1] + ' ' + x[2] + ', ' + x[5]
    date_created.append(parse(dt).date())
    
user_data['acct_create_time'] = time_created
user_data['acct_create_date'] = date_created

#3. Drop user_created_at column
user_data = user_data.drop('user_created_at', axis = 1)

user_data.head()
# Out:
#   user_lang                   user_location user_screen_name     user_id  \
# 0        en                 California, USA    UltraYOUwoman  3188618684
# 1        en                  Miami, Florida        yungcutup    18387174
# 2        en                Indianapolis, IN      rachelbogle    32645612
# 3        en  Tennessee by way of New Jersey      ErvGotti609   175932740
# 4        en                     Gambleville     NoLuckNeeded    22306628
#
#   acct_create_time acct_create_date
# 0         10:27:51       2015-05-08
# 1         09:30:23       2008-12-26
# 2         23:04:15       2009-04-17
# 3         02:02:56       2010-08-08
# 4         23:13:57       2009-02-28

# %%
#Dedupe user_data --> Next in SQL, make user ID a primary key
#==============================================

user_data = user_data.drop_duplicates()
user_data.head()
# Out:
#   user_lang                   user_location user_screen_name     user_id  \
# 0        en                 California, USA    UltraYOUwoman  3188618684
# 1        en                  Miami, Florida        yungcutup    18387174
# 2        en                Indianapolis, IN      rachelbogle    32645612
# 3        en  Tennessee by way of New Jersey      ErvGotti609   175932740
# 4        en                     Gambleville     NoLuckNeeded    22306628
#
#   acct_create_time acct_create_date
# 0         10:27:51       2015-05-08
# 1         09:30:23       2008-12-26
# 2         23:04:15       2009-04-17
# 3         02:02:56       2010-08-08
# 4         23:13:57       2009-02-28

# %%
#Clean tweet data
#==============================================

#1. Separate date and time
split_datetime = tweet_data['tweet_created_at'].str.split()

#2. Tweet time and Tweet date columns
time_created = []
date_created = []

for x in split_datetime:
    time_created.append(x[3])
    dt = x[1] + ' ' + x[2] + ', ' + x[5]
    date_created.append(parse(dt).date())
    
tweet_data['tweet_time'] = time_created
tweet_data['tweet_date'] = date_created

tweet_data.head()

#3. Get tweet user ID
tuser = tweet_data['tweet_user'].str.replace(',', '')
tuser2 = tuser.str.split()
tweet_data['tweet_user_id'] = [x[1] for x in tuser2]

#4. Extract tweet source url
url0 = tweet_data['tweet_source'].str.split()
tweet_data['tweet_source_url']=[x[1].split('"')[1] for x in url0]

#5 Extract #'s by searching for # from tweet_full_text
a = tweet_data['tweet_full_text'].str.split(" ")
f = []
for i in a:
    k = pd.Series(i).str.startswith("#") 
    j = [i for i, x in enumerate(k) if x]
    #hashtag = ""
    
    hashtag = []
    for y in j:
        #b = (hashtag + ' | ' + i[y]).strip(' | ')
        hashtag.append(i[y])
        
    f.append(hashtag)
tweet_data['hashtags'] = f
# Out:
# C:\Users\shuashua\Anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\shuashua\Anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\shuashua\Anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\shuashua\Anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\shuashua\Anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#* Drop unwanted columns
tweet_data_clean = tweet_data[['tweet_time', 'tweet_date', 'tweet_user_id', 'tweet_source_url', 'hashtags', 'tweet_full_text']]
tweet_data_clean.head()
# Out:
#   tweet_time  tweet_date tweet_user_id                    tweet_source_url  \
# 0   16:25:06  2018-09-07    3188618684              https://statusbrew.com
# 1   16:24:59  2018-09-07      18387174     http://www.facebook.com/twitter
# 2   16:24:50  2018-09-07      32645612  http://twitter.com/download/iphone
# 3   16:24:44  2018-09-07     175932740                http://instagram.com
# 4   16:24:39  2018-09-07      22306628                  http://twitter.com
#
#                                             hashtags  \
# 0                   #quote | #motivation | #justdoit
# 1  #fdny | #likesforlikes | #promo | #music | #in...
# 2               #4YourMorning | #4YourMemeCollection
# 3             #kapernickeffect | #swoosh | #justdoit
# 4  #shaquem | #NFL | #Seattle | #Seahawks | #grif...
#
#                                      tweet_full_text
# 0  Done is better than perfect. — Sheryl Sandberg...
# 1  Shout out to the Great Fire Department and the...
# 2  There are some AMAZINGLY hilarious Nike Ad mem...
# 3  #kapernickeffect #swoosh #justdoit @ Lucas Bis...
# 4  One Hand, One Dream: The Shaquem Griffin Story...

# %%
############ Source Two #################
## Web scrape http://best-hashtags.com for Most popular instagram justdoit hashtags
url = 'http://best-hashtags.com/hashtag/justdoit/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

# %%
#1. Find all related #'s and create a data frame
top_hashtags = soup.find('div', class_="tag-box tag-box-v3 margin-bottom-40").p1.text
Most_popular_instagram_justdoit_hashtags = pd.DataFrame(top_hashtags.split())
Most_popular_instagram_justdoit_hashtags.columns= ['Hashtags']
Most_popular_instagram_justdoit_hashtags2 = Most_popular_instagram_justdoit_hashtags[Most_popular_instagram_justdoit_hashtags['Hashtags'] != '#justdoit']

#2. Drop #justdoit from data frame since Source One is pulled by restrictions to tweets with this #, so when using this 
# dataset later we don't get a 100% match.

# %%
## convert only column in data from to list
popular_list = Most_popular_instagram_justdoit_hashtags2['Hashtags'].values.tolist()
popular_list
# Out:
# ['#fitness',
#  '#gym',
#  '#workout',
#  '#motivation',
#  '#nike',
#  '#training',
#  '#fit',
#  '#healthy',
#  '#love',
#  '#fitnessmotivation',
#  '#health',
#  '#bodybuilding',
#  '#fitfam',
#  '#goals',
#  '#fitspo',
#  '#healthylifestyle',
#  '#running',
#  '#active',
#  '#train',
#  '#sport',
#  '#sports',
#  '#run',
#  '#getfit',
#  '#fitnessmodel',
#  '#gymlife',
#  '#excercise',
#  '#best',
#  '#lifestyle',
#  '#bhfyp']

# %%
## Add popular_hashtag_flag to tweet_data

J = []
for ht in tweet_data['hashtags']:
    s = pd.Series(ht)
    #print(s)
    popular_hashtag_flag = 0
    for i in popular_list:
        #print(i)
        if i in ht:
            #print("1")
            popular_hashtag_flag = popular_hashtag_flag + 1
        else:
            #print(0)
            popular_hashtag_flag = popular_hashtag_flag + 0
    J.append(popular_hashtag_flag)
tweet_data['popular_hashtag_flag'] = J
# Out:
# C:\Users\shuashua\Anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
tweet_data
# Out:
#                     tweet_created_at  \
# 0     Fri Sep 07 16:25:06 +0000 2018
# 1     Fri Sep 07 16:24:59 +0000 2018
# 2     Fri Sep 07 16:24:50 +0000 2018
# 3     Fri Sep 07 16:24:44 +0000 2018
# 4     Fri Sep 07 16:24:39 +0000 2018
# 5     Fri Sep 07 16:24:35 +0000 2018
# 6     Fri Sep 07 16:24:24 +0000 2018
# 7     Fri Sep 07 16:24:13 +0000 2018
# 8     Fri Sep 07 16:24:09 +0000 2018
# 9     Fri Sep 07 16:23:51 +0000 2018
# 10    Fri Sep 07 16:23:41 +0000 2018
# 11    Fri Sep 07 16:23:40 +0000 2018
# 12    Fri Sep 07 16:23:37 +0000 2018
# 13    Fri Sep 07 16:23:30 +0000 2018
# 14    Fri Sep 07 16:23:27 +0000 2018
# 15    Fri Sep 07 16:23:21 +0000 2018
# 16    Fri Sep 07 16:23:17 +0000 2018
# 17    Fri Sep 07 16:23:09 +0000 2018
# 18    Fri Sep 07 16:23:02 +0000 2018
# 19    Fri Sep 07 16:22:55 +0000 2018
# 20    Fri Sep 07 16:22:41 +0000 2018
# 21    Fri Sep 07 16:22:19 +0000 2018
# 22    Fri Sep 07 16:21:55 +0000 2018
# 23    Fri Sep 07 16:21:54 +0000 2018
# 24    Fri Sep 07 16:21:41 +0000 2018
# 25    Fri Sep 07 16:21:39 +0000 2018
# 26    Fri Sep 07 16:21:28 +0000 2018
# 27    Fri Sep 07 16:21:25 +0000 2018
# 28    Fri Sep 07 16:21:12 +0000 2018
# 29    Fri Sep 07 16:21:09 +0000 2018
# ...                              ...
# 5059  Fri Sep 07 00:21:21 +0000 2018
# 5060  Fri Sep 07 00:21:21 +0000 2018
# 5061  Fri Sep 07 00:21:12 +0000 2018
# 5062  Fri Sep 07 00:21:00 +0000 2018
# 5063  Fri Sep 07 00:20:36 +0000 2018
# 5064  Fri Sep 07 00:20:36 +0000 2018
# 5065  Fri Sep 07 00:20:07 +0000 2018
# 5066  Fri Sep 07 00:20:06 +0000 2018
# 5067  Fri Sep 07 00:20:04 +0000 2018
# 5068  Fri Sep 07 00:20:02 +0000 2018
# 5069  Fri Sep 07 00:20:02 +0000 2018
# 5070  Fri Sep 07 00:20:01 +0000 2018
# 5071  Fri Sep 07 00:19:55 +0000 2018
# 5072  Fri Sep 07 00:19:47 +0000 2018
# 5073  Fri Sep 07 00:19:44 +0000 2018
# 5074  Fri Sep 07 00:19:37 +0000 2018
# 5075  Fri Sep 07 00:19:33 +0000 2018
# 5076  Fri Sep 07 00:19:28 +0000 2018
# 5077  Fri Sep 07 00:19:15 +0000 2018
# 5078  Fri Sep 07 00:19:01 +0000 2018
# 5079  Fri Sep 07 00:18:53 +0000 2018
# 5080  Fri Sep 07 00:18:43 +0000 2018
# 5081  Fri Sep 07 00:18:29 +0000 2018
# 5082  Fri Sep 07 00:18:25 +0000 2018
# 5083  Fri Sep 07 00:18:25 +0000 2018
# 5084  Fri Sep 07 00:18:24 +0000 2018
# 5085  Fri Sep 07 00:18:14 +0000 2018
# 5086  Fri Sep 07 00:18:05 +0000 2018
# 5087  Fri Sep 07 00:17:49 +0000 2018
# 5088  Fri Sep 07 00:17:13 +0000 2018
#
#                                          tweet_entities  \
# 0     {'hashtags': [{'text': 'quote', 'indices': [47...
# 1     {'hashtags': [{'text': 'hero', 'indices': [90,...
# 2     {'hashtags': [{'text': 'JustDoIt', 'indices': ...
# 3     {'hashtags': [{'text': 'kapernickeffect', 'ind...
# 4     {'hashtags': [{'text': 'shaquem', 'indices': [...
# 5     {'hashtags': [{'text': 'JUSTDOIT', 'indices': ...
# 6     {'hashtags': [{'text': 'RegisterToVote', 'indi...
# 7     {'hashtags': [{'text': 'JustDoIt', 'indices': ...
# 8     {'hashtags': [{'text': 'JustDoIt', 'indices': ...
# 9     {'hashtags': [{'text': 'FX', 'indices': [48, 5...
# 10    {'hashtags': [{'text': 'JustDoIt', 'indices': ...
# 11    {'hashtags': [{'text': 'NikeBoycott', 'indices...
# 12    {'hashtags': [{'text': 'JustDoIt', 'indices': ...
# 13    {'hashtags': [{'text': 'JustDoIt', 'indices': ...
# 14    {'hashtags': [{'text': 'JustDoIt', 'indices': ...
# 15    {'hashtags': [{'text': 'JustDoIt', 'indices': ...
# 16    {'hashtags': [{'text': 'socialism', 'indices':...
# 17    {'hashtags': [{'text': 'JustDoIt', 'indices': ...
# 18    {'hashtags': [{'text': 'JustDoIt', 'indices': ...
# 19    {'hashtags': [{'text': 'Kavanaugh', 'indices':...
# 20    {'hashtags': [{'text': 'JustDoIt', 'indices': ...
# 21    {'hashtags': [{'text': 'nike', 'indices': [154...
# 22    {'hashtags': [{'text': 'Discounts365days', 'in...
# 23    {'hashtags': [{'text': 'Justdoit', 'indices': ...
# 24    {'hashtags': [{'text': 'Justdoit', 'indices': ...
# 25    {'hashtags': [{'text': 'newyoutubers', 'indice...
# 26    {'hashtags': [{'text': 'JustDoIt', 'indices': ...
# 27    {'hashtags': [{'text': 'NikeStrong', 'indices'...
# 28    {'hashtags': [{'text': 'justdoit', 'indices': ...
# 29    {'hashtags': [{'text': 'legday', 'indices': [2...
# ...                                                 ...
# 5059  {'hashtags': [{'text': 'Justdoit', 'indices': ...
# 5060  {'hashtags': [{'text': 'Rawkngrub', 'indices':...
# 5061  {'hashtags': [{'text': 'BookRecommendations', ...
# 5062  {'hashtags': [{'text': 'kermitgetsfit', 'indic...
# 5063  {'hashtags': [{'text': 'JustDoIt', 'indices': ...
# 5064  {'hashtags': [{'text': 'justdoit', 'indices': ...
# 5065  {'hashtags': [{'text': 'JustDoIt', 'indices': ...
# 5066  {'hashtags': [{'text': 'JustDoIt', 'indices': ...
# 5067  {'hashtags': [{'text': 'JustDoIt', 'indices': ...
# 5068  {'hashtags': [{'text': 'HisRoadTrip', 'indices...
# 5069  {'hashtags': [{'text': 'Mrhoffaatme', 'indices...
# 5070  {'hashtags': [{'text': 'FortyFive', 'indices':...
# 5071  {'hashtags': [{'text': 'justdoit', 'indices': ...
# 5072  {'hashtags': [{'text': 'JustDoIt', 'indices': ...
# 5073  {'hashtags': [{'text': 'dontburnyourshoes', 'i...
# 5074  {'hashtags': [{'text': 'JustDoIt', 'indices': ...
# 5075  {'hashtags': [{'text': 'JustDoIt', 'indices': ...
# 5076  {'hashtags': [{'text': 'believeinsomething', '...
# 5077  {'hashtags': [{'text': 'justdoit', 'indices': ...
# 5078  {'hashtags': [{'text': 'UsOpen', 'indices': [6...
# 5079  {'hashtags': [{'text': 'JustDoIt', 'indices': ...
# 5080  {'hashtags': [{'text': 'Houston', 'indices': [...
# 5081  {'hashtags': [{'text': 'JustDoIt', 'indices': ...
# 5082  {'hashtags': [{'text': 'juststringit', 'indice...
# 5083  {'hashtags': [{'text': 'PHIvsATL', 'indices': ...
# 5084  {'hashtags': [{'text': 'JustDoIt', 'indices': ...
# 5085  {'hashtags': [{'text': 'MGK', 'indices': [31, ...
# 5086  {'hashtags': [{'text': 'MamaSaidKnockYouOut', ...
# 5087  {'hashtags': [{'text': 'USOpen2018', 'indices'...
# 5088  {'hashtags': [{'text': 'Justdoit', 'indices': ...
#
#                                 tweet_extended_entities  tweet_favorite_count  \
# 0     {'media': [{'id': 1038100853872197632, 'id_str...                     0
# 1                                                   NaN                     0
# 2     {'media': [{'id': 1038100773396041728, 'id_str...                     0
# 3                                                   NaN                     0
# 4     {'media': [{'id': 1038100736595255296, 'id_str...                     0
# 5                                                   NaN                     0
# 6                                                   NaN                     0
# 7                                                   NaN                     0
# 8     {'media': [{'id': 1038099973278244864, 'id_str...                     0
# 9     {'media': [{'id': 1038100525554827266, 'id_str...                     0
# 10    {'media': [{'id': 1038100496085446657, 'id_str...                     0
# 11                                                  NaN                     0
# 12                                                  NaN                     0
# 13                                                  NaN                     0
# 14                                                  NaN                     0
# 15                                                  NaN                     0
# 16                                                  NaN                     0
# 17                                                  NaN                     1
# 18    {'media': [{'id': 1038100330175758336, 'id_str...                     3
# 19                                                  NaN                     0
# 20                                                  NaN                     0
# 21    {'media': [{'id': 1038100153335533568, 'id_str...                     0
# 22    {'media': [{'id': 1038099994715271168, 'id_str...                     2
# 23                                                  NaN                     0
# 24                                                  NaN                     0
# 25    {'media': [{'id': 1038099976381845504, 'id_str...                     0
# 26                                                  NaN                     0
# 27                                                  NaN                     0
# 28    {'media': [{'id': 1038099814980956162, 'id_str...                     0
# 29                                                  NaN                     2
# ...                                                 ...                   ...
# 5059                                                NaN                     0
# 5060                                                NaN                     0
# 5061  {'media': [{'id': 1037858246936027138, 'id_str...                     5
# 5062                                                NaN                     3
# 5063                                                NaN                     7
# 5064                                                NaN                     5
# 5065                                                NaN                     0
# 5066  {'media': [{'id': 1037857997131800582, 'id_str...                    18
# 5067                                                NaN                     0
# 5068  {'media': [{'id': 1037857992501276672, 'id_str...                     0
# 5069  {'media': [{'id': 1037857953905291264, 'id_str...                     1
# 5070  {'media': [{'id': 1037857973136109568, 'id_str...                     1
# 5071                                                NaN                     0
# 5072                                                NaN                     1
# 5073                                                NaN                     2
# 5074  {'media': [{'id': 1037857875987705857, 'id_str...                     0
# 5075                                                NaN                     0
# 5076                                                NaN                     0
# 5077                                                NaN                     0
# 5078  {'media': [{'id': 1037857724850040832, 'id_str...                     3
# 5079                                                NaN                     0
# 5080                                                NaN                     0
# 5081  {'media': [{'id': 1037857582507913217, 'id_str...                    16
# 5082  {'media': [{'id': 1037857575386185728, 'id_str...                     1
# 5083                                                NaN                     0
# 5084                                                NaN                     0
# 5085  {'media': [{'id': 1037857533178855424, 'id_str...                     0
# 5086                                                NaN                     0
# 5087                                                NaN                     0
# 5088                                                NaN                     1
#
#       tweet_favorited                                    tweet_full_text  \
# 0               False  Done is better than perfect. — Sheryl Sandberg...
# 1               False  Shout out to the Great Fire Department and the...
# 2               False  There are some AMAZINGLY hilarious Nike Ad mem...
# 3               False  #kapernickeffect #swoosh #justdoit @ Lucas Bis...
# 4               False  One Hand, One Dream: The Shaquem Griffin Story...
# 5               False  @realDonaldTrump It's time for me to stock up ...
# 6               False  Why won't Trump protect our elections?  Think ...
# 7               False  @Nike good job on shaking the whole world, i s...
# 8               False  GREAT way to meet good people...wearing your N...
# 9               False  Lead,Trade and Succeed with ICM\nPlease retwee...
# 10              False  My favorites so far #JustDoIt https://t.co/zY7...
# 11              False  Colin Kaepernick's business partner @Nike send...
# 12              False  @CSPensions Why be a cat when you can be a lio...
# 13              False  @realDonaldTrump They were thinking history wi...
# 14              False  @RepAdamSchiff Go ahead @RepAdamSchiff   #Just...
# 15              False  Why be a cat when you can be a lion. #JustDoIt...
# 16              False  #socialism be like me and #JustDoIt because ya...
# 17              False  Hey @Nike I stood for our country. I served my...
# 18              False  I’ve seen a lot of memes re #JustDoIt but this...
# 19              False  Abortion stops a beating heart. Just imagine a...
# 20              False  @Nike My favorite Nike commercial ever!! #Just...
# 21              False  Modeling is more than just runway and clothes ...
# 22              False  You are never too broke to shop your favourite...
# 23              False  My kinda Lady ... #Justdoit #Nike !!! https://...
# 24              False  Dream Big &amp; #Justdoit! https://t.co/Vr4GIy...
# 25              False  Hey!!!! go check this video out !!! It’s a lot...
# 26              False  Nike got $43 million of free press in the 24 h...
# 27              False  @realDonaldTrump They were thinking - “let’s u...
# 28              False  YOU STOLE MY GODDAMN HOUSE #justdoit #juststea...
# 29              False  Don't skip leg day y'all #legday #justdoit #fl...
# ...               ...                                                ...
# 5059            False  Just believe in something! #Justdoit https://t...
# 5060            False  Try the #Rawkngrub food truck. Like Nike...#ju...
# 5061            False  Talk about out of their comfort zone...they we...
# 5062            False  #kermitgetsfit with #tireflips today!! CrossFi...
# 5063            False  As your constituent, I’m disgusted by your act...
# 5064            False  Everyone needs to stop worrying about Nike and...
# 5065            False  The @Nike @Kaepernick7 ad well worth the contr...
# 5066            False  Most people forget 🤦🏾‍♂️ #JustDoIt https://t.c...
# 5067            False  @BuckSexton #JustDoIt #WalkAway from Twitter #...
# 5068            False  BEAUTIFUL FALLS read them #HisRoadTrip #Travel...
# 5069            False  OUT NOW... 🏀🏀🏀🏀\nProd.BEATZERA #Mrhoffaatme #M...
# 5070            False  I did a thing @Nike @realDonaldTrump #FortyFiv...
# 5071            False  You can’t be mad at Nike and you still eatin P...
# 5072            False  After 24 years of sacrifice so they can do thi...
# 5073            False  #dontburnyourshoes #boxing #boxingbootcamp  #b...
# 5074            False  .@Nike #JustDoIt LOL congratulations!!! https:...
# 5075            False  Nike been sponsoring black athletes, now it’s ...
# 5076            False  Take a knee??? Not me!!!  #believeinsomething ...
# 5077            False  @nike is dropping these flameOn’s at midnight ...
# 5078            False  Watching @serenawilliams play is really a thin...
# 5079            False  @realDonaldTrump Drop it Sir, Drop the 20 unre...
# 5080            False  @HoustonRockets @carmeloanthony my Brother I d...
# 5081            False  Thanks Kaepernick. #JustDoIt https://t.co/3pOH...
# 5082            False  We've bled for it... #juststringit \n\n #belie...
# 5083            False  So we gotta wait even longer for that @Kaepern...
# 5084            False  We have what we need.  #JustDoIt https://t.co/...
# 5085            False  Even the best can take an L!!\n\n#MGK #RapDevi...
# 5086            False  Serena! All Serena, 9 of the last 10 games. If...
# 5087            False  @serenawilliams #USOpen2018 Tearing it up your...
# 5088            False  WOW the Nike #Justdoit add they played before ...
#
#      tweet_lang                                     tweet_metadata  \
# 0            en  {'iso_language_code': 'en', 'result_type': 're...
# 1            en  {'iso_language_code': 'en', 'result_type': 're...
# 2            en  {'iso_language_code': 'en', 'result_type': 're...
# 3            en  {'iso_language_code': 'en', 'result_type': 're...
# 4            en  {'iso_language_code': 'en', 'result_type': 're...
# 5            en  {'iso_language_code': 'en', 'result_type': 're...
# 6            en  {'iso_language_code': 'en', 'result_type': 're...
# 7            en  {'iso_language_code': 'en', 'result_type': 're...
# 8            en  {'iso_language_code': 'en', 'result_type': 're...
# 9            en  {'iso_language_code': 'en', 'result_type': 're...
# 10           en  {'iso_language_code': 'en', 'result_type': 're...
# 11           en  {'iso_language_code': 'en', 'result_type': 're...
# 12           en  {'iso_language_code': 'en', 'result_type': 're...
# 13           en  {'iso_language_code': 'en', 'result_type': 're...
# 14           en  {'iso_language_code': 'en', 'result_type': 're...
# 15           en  {'iso_language_code': 'en', 'result_type': 're...
# 16           en  {'iso_language_code': 'en', 'result_type': 're...
# 17           en  {'iso_language_code': 'en', 'result_type': 're...
# 18           en  {'iso_language_code': 'en', 'result_type': 're...
# 19           en  {'iso_language_code': 'en', 'result_type': 're...
# 20           en  {'iso_language_code': 'en', 'result_type': 're...
# 21           en  {'iso_language_code': 'en', 'result_type': 're...
# 22           en  {'iso_language_code': 'en', 'result_type': 're...
# 23           en  {'iso_language_code': 'en', 'result_type': 're...
# 24           en  {'iso_language_code': 'en', 'result_type': 're...
# 25           en  {'iso_language_code': 'en', 'result_type': 're...
# 26           en  {'iso_language_code': 'en', 'result_type': 're...
# 27           en  {'iso_language_code': 'en', 'result_type': 're...
# 28           en  {'iso_language_code': 'en', 'result_type': 're...
# 29           en  {'iso_language_code': 'en', 'result_type': 're...
# ...         ...                                                ...
# 5059         en  {'iso_language_code': 'en', 'result_type': 're...
# 5060         en  {'iso_language_code': 'en', 'result_type': 're...
# 5061         en  {'iso_language_code': 'en', 'result_type': 're...
# 5062         en  {'iso_language_code': 'en', 'result_type': 're...
# 5063         en  {'iso_language_code': 'en', 'result_type': 're...
# 5064         en  {'iso_language_code': 'en', 'result_type': 're...
# 5065         en  {'iso_language_code': 'en', 'result_type': 're...
# 5066         en  {'iso_language_code': 'en', 'result_type': 're...
# 5067         en  {'iso_language_code': 'en', 'result_type': 're...
# 5068         en  {'iso_language_code': 'en', 'result_type': 're...
# 5069         en  {'iso_language_code': 'en', 'result_type': 're...
# 5070         en  {'iso_language_code': 'en', 'result_type': 're...
# 5071         en  {'iso_language_code': 'en', 'result_type': 're...
# 5072         en  {'iso_language_code': 'en', 'result_type': 're...
# 5073         en  {'iso_language_code': 'en', 'result_type': 're...
# 5074         en  {'iso_language_code': 'en', 'result_type': 're...
# 5075         en  {'iso_language_code': 'en', 'result_type': 're...
# 5076         en  {'iso_language_code': 'en', 'result_type': 're...
# 5077         en  {'iso_language_code': 'en', 'result_type': 're...
# 5078         en  {'iso_language_code': 'en', 'result_type': 're...
# 5079         en  {'iso_language_code': 'en', 'result_type': 're...
# 5080         en  {'iso_language_code': 'en', 'result_type': 're...
# 5081         en  {'iso_language_code': 'en', 'result_type': 're...
# 5082         en  {'iso_language_code': 'en', 'result_type': 're...
# 5083         en  {'iso_language_code': 'en', 'result_type': 're...
# 5084         en  {'iso_language_code': 'en', 'result_type': 're...
# 5085         en  {'iso_language_code': 'en', 'result_type': 're...
# 5086         en  {'iso_language_code': 'en', 'result_type': 're...
# 5087         en  {'iso_language_code': 'en', 'result_type': 're...
# 5088         en  {'iso_language_code': 'en', 'result_type': 're...
#
#      tweet_possibly_sensitive  tweet_retweet_count  tweet_retweeted  \
# 0                       False                    0            False
# 1                       False                    0            False
# 2                       False                    0            False
# 3                       False                    0            False
# 4                       False                    0            False
# 5                         NaN                    0            False
# 6                       False                    0            False
# 7                         NaN                    0            False
# 8                       False                    0            False
# 9                       False                    0            False
# 10                      False                    0            False
# 11                      False                    0            False
# 12                        NaN                    0            False
# 13                        NaN                    0            False
# 14                        NaN                    0            False
# 15                      False                    0            False
# 16                      False                    0            False
# 17                        NaN                    1            False
# 18                      False                    1            False
# 19                        NaN                    0            False
# 20                        NaN                    0            False
# 21                      False                    0            False
# 22                      False                    0            False
# 23                      False                    0            False
# 24                      False                    0            False
# 25                      False                    0            False
# 26                        NaN                    0            False
# 27                        NaN                    0            False
# 28                      False                    0            False
# 29                      False                    0            False
# ...                       ...                  ...              ...
# 5059                    False                    0            False
# 5060                      NaN                    0            False
# 5061                    False                    0            False
# 5062                    False                    0            False
# 5063                    False                    4            False
# 5064                      NaN                    1            False
# 5065                      NaN                    0            False
# 5066                    False                    8            False
# 5067                      NaN                    0            False
# 5068                    False                    0            False
# 5069                    False                    0            False
# 5070                    False                    0            False
# 5071                      NaN                    2            False
# 5072                    False                    0            False
# 5073                    False                    0            False
# 5074                    False                    0            False
# 5075                    False                    0            False
# 5076                    False                    0            False
# 5077                    False                    0            False
# 5078                    False                    0            False
# 5079                      NaN                    0            False
# 5080                      NaN                    0            False
# 5081                    False                    0            False
# 5082                    False                    0            False
# 5083                      NaN                    0            False
# 5084                    False                    0            False
# 5085                    False                    0            False
# 5086                      NaN                    0            False
# 5087                      NaN                    0            False
# 5088                      NaN                    0            False
#
#                                            tweet_source  tweet_truncated  \
# 0     <a href="https://statusbrew.com" rel="nofollow...            False
# 1     <a href="http://www.facebook.com/twitter" rel=...            False
# 2     <a href="http://twitter.com/download/iphone" r...            False
# 3     <a href="http://instagram.com" rel="nofollow">...            False
# 4     <a href="http://twitter.com" rel="nofollow">Tw...            False
# 5     <a href="http://twitter.com/download/iphone" r...            False
# 6     <a href="http://twitter.com" rel="nofollow">Tw...            False
# 7     <a href="http://twitter.com/download/iphone" r...            False
# 8     <a href="http://twitter.com" rel="nofollow">Tw...            False
# 9     <a href="http://twitter.com/download/android" ...            False
# 10    <a href="http://twitter.com/download/iphone" r...            False
# 11    <a href="http://twitter.com" rel="nofollow">Tw...            False
# 12    <a href="https://mobile.twitter.com" rel="nofo...            False
# 13    <a href="http://twitter.com/download/iphone" r...            False
# 14    <a href="http://twitter.com/download/iphone" r...            False
# 15    <a href="https://mobile.twitter.com" rel="nofo...            False
# 16    <a href="http://www.linkedin.com/" rel="nofoll...            False
# 17    <a href="http://twitter.com/download/android" ...            False
# 18    <a href="http://twitter.com/download/iphone" r...            False
# 19    <a href="http://twitter.com/download/android" ...            False
# 20    <a href="http://twitter.com/download/iphone" r...            False
# 21    <a href="http://twitter.com/download/iphone" r...            False
# 22    <a href="http://twitter.com" rel="nofollow">Tw...            False
# 23    <a href="http://instagram.com" rel="nofollow">...            False
# 24    <a href="http://www.facebook.com/twitter" rel=...            False
# 25    <a href="https://mobile.twitter.com" rel="nofo...            False
# 26    <a href="http://twitter.com" rel="nofollow">Tw...            False
# 27    <a href="http://twitter.com/download/iphone" r...            False
# 28    <a href="http://twitter.com" rel="nofollow">Tw...            False
# 29    <a href="http://instagram.com" rel="nofollow">...            False
# ...                                                 ...              ...
# 5059  <a href="http://twitter.com" rel="nofollow">Tw...            False
# 5060  <a href="http://twitter.com/download/iphone" r...            False
# 5061  <a href="http://twitter.com/download/iphone" r...            False
# 5062  <a href="http://instagram.com" rel="nofollow">...            False
# 5063  <a href="http://twitter.com/download/iphone" r...            False
# 5064  <a href="http://twitter.com/download/iphone" r...            False
# 5065  <a href="http://twitter.com/download/iphone" r...            False
# 5066  <a href="http://twitter.com/download/iphone" r...            False
# 5067  <a href="http://janetter.net/" rel="nofollow">...            False
# 5068  <a href="https://buffer.com" rel="nofollow">Bu...            False
# 5069  <a href="http://twitter.com/download/android" ...            False
# 5070  <a href="http://twitter.com/download/android" ...            False
# 5071  <a href="http://twitter.com/download/iphone" r...            False
# 5072  <a href="http://twitter.com/download/iphone" r...            False
# 5073  <a href="http://instagram.com" rel="nofollow">...            False
# 5074  <a href="http://twitter.com" rel="nofollow">Tw...            False
# 5075  <a href="http://twitter.com/download/iphone" r...            False
# 5076  <a href="http://instagram.com" rel="nofollow">...            False
# 5077  <a href="http://instagram.com" rel="nofollow">...            False
# 5078  <a href="http://twitter.com/download/android" ...            False
# 5079  <a href="http://twitter.com" rel="nofollow">Tw...            False
# 5080  <a href="http://twitter.com/download/android" ...            False
# 5081  <a href="http://twitter.com/download/android" ...            False
# 5082  <a href="http://twitter.com/download/android" ...            False
# 5083  <a href="http://twitter.com/download/iphone" r...            False
# 5084  <a href="http://twitter.com/download/android" ...            False
# 5085  <a href="http://twitter.com/download/android" ...            False
# 5086  <a href="https://about.twitter.com/products/tw...            False
# 5087  <a href="http://twitter.com/download/iphone" r...            False
# 5088  <a href="http://twitter.com/download/iphone" r...            False
#
#                                              tweet_user  \
# 0     {'id': 3188618684, 'id_str': '3188618684', 'na...
# 1     {'id': 18387174, 'id_str': '18387174', 'name':...
# 2     {'id': 32645612, 'id_str': '32645612', 'name':...
# 3     {'id': 175932740, 'id_str': '175932740', 'name...
# 4     {'id': 22306628, 'id_str': '22306628', 'name':...
# 5     {'id': 15566700, 'id_str': '15566700', 'name':...
# 6     {'id': 174307749, 'id_str': '174307749', 'name...
# 7     {'id': 743856280717172737, 'id_str': '74385628...
# 8     {'id': 21149200, 'id_str': '21149200', 'name':...
# 9     {'id': 1032243057746472960, 'id_str': '1032243...
# 10    {'id': 287412793, 'id_str': '287412793', 'name...
# 11    {'id': 538533358, 'id_str': '538533358', 'name...
# 12    {'id': 305589676, 'id_str': '305589676', 'name...
# 13    {'id': 2442615413, 'id_str': '2442615413', 'na...
# 14    {'id': 42350706, 'id_str': '42350706', 'name':...
# 15    {'id': 305589676, 'id_str': '305589676', 'name...
# 16    {'id': 795020884167770112, 'id_str': '79502088...
# 17    {'id': 1096452331, 'id_str': '1096452331', 'na...
# 18    {'id': 981897559705780224, 'id_str': '98189755...
# 19    {'id': 462683900, 'id_str': '462683900', 'name...
# 20    {'id': 1511279516, 'id_str': '1511279516', 'na...
# 21    {'id': 51053193, 'id_str': '51053193', 'name':...
# 22    {'id': 804501012, 'id_str': '804501012', 'name...
# 23    {'id': 258403085, 'id_str': '258403085', 'name...
# 24    {'id': 2888891305, 'id_str': '2888891305', 'na...
# 25    {'id': 411002863, 'id_str': '411002863', 'name...
# 26    {'id': 89155743, 'id_str': '89155743', 'name':...
# 27    {'id': 34295011, 'id_str': '34295011', 'name':...
# 28    {'id': 167540418, 'id_str': '167540418', 'name...
# 29    {'id': 105285304, 'id_str': '105285304', 'name...
# ...                                                 ...
# 5059  {'id': 11391972, 'id_str': '11391972', 'name':...
# 5060  {'id': 271644186, 'id_str': '271644186', 'name...
# 5061  {'id': 897496620169916416, 'id_str': '89749662...
# 5062  {'id': 506914758, 'id_str': '506914758', 'name...
# 5063  {'id': 70101580, 'id_str': '70101580', 'name':...
# 5064  {'id': 1022654087861624832, 'id_str': '1022654...
# 5065  {'id': 1936605001, 'id_str': '1936605001', 'na...
# 5066  {'id': 1343210436, 'id_str': '1343210436', 'na...
# 5067  {'id': 56275127, 'id_str': '56275127', 'name':...
# 5068  {'id': 810577073882468353, 'id_str': '81057707...
# 5069  {'id': 983642053199519744, 'id_str': '98364205...
# 5070  {'id': 113451238, 'id_str': '113451238', 'name...
# 5071  {'id': 37323921, 'id_str': '37323921', 'name':...
# 5072  {'id': 3156919382, 'id_str': '3156919382', 'na...
# 5073  {'id': 37728562, 'id_str': '37728562', 'name':...
# 5074  {'id': 115983717, 'id_str': '115983717', 'name...
# 5075  {'id': 354992778, 'id_str': '354992778', 'name...
# 5076  {'id': 475211280, 'id_str': '475211280', 'name...
# 5077  {'id': 265534179, 'id_str': '265534179', 'name...
# 5078  {'id': 243502692, 'id_str': '243502692', 'name...
# 5079  {'id': 23797371, 'id_str': '23797371', 'name':...
# 5080  {'id': 62734932, 'id_str': '62734932', 'name':...
# 5081  {'id': 47207414, 'id_str': '47207414', 'name':...
# 5082  {'id': 2842070309, 'id_str': '2842070309', 'na...
# 5083  {'id': 431106722, 'id_str': '431106722', 'name...
# 5084  {'id': 17514726, 'id_str': '17514726', 'name':...
# 5085  {'id': 798157472263446532, 'id_str': '79815747...
# 5086  {'id': 16634486, 'id_str': '16634486', 'name':...
# 5087  {'id': 126147359, 'id_str': '126147359', 'name...
# 5088  {'id': 28454708, 'id_str': '28454708', 'name':...
#
#                                                hashtags tweet_time  \
# 0                      [#quote, #motivation, #justdoit]   16:25:06
# 1     [#fdny, #likesforlikes, #promo, #music, #insta...   16:24:59
# 2                 [#4YourMorning, #4YourMemeCollection]   16:24:50
# 3                [#kapernickeffect, #swoosh, #justdoit]   16:24:44
# 4     [#shaquem, #NFL, #Seattle, #Seahawks, #griffin...   16:24:39
# 5                                           [#JUSTDOIT]   16:24:35
# 6                          [#RegisterToVote, #JustDoIt]   16:24:24
# 7                                           [#JustDoIt]   16:24:13
# 8            [#JustDoIt, #TakeAKnee, #TakeAKneeInNikes]   16:24:09
# 9     [#FeelGoodFriday, #FridayFeeling, #TRADERMONI,...   16:23:51
# 10                                          [#JustDoIt]   16:23:41
# 11    [#NikeBoycott, #JustDoIt\n\nhttps://t.co/abSV7...   16:23:40
# 12                                          [#JustDoIt]   16:23:37
# 13                                          [#JustDoIt]   16:23:30
# 14                           [#JustDoIt, #SpartacAssJr]   16:23:27
# 15                                          [#JustDoIt]   16:23:21
# 16    [#socialism, #JustDoIt, #kaga2018, #kag2020, #...   16:23:17
# 17                                          [#JustDoIt]   16:23:09
# 18                            [#JustDoIt, #VoteRed2018]   16:23:02
# 19                              [#Kavanaugh, #justdoit]   16:22:55
# 20                                          [#JustDoIt]   16:22:41
# 21    [#nike, #kaepernick7, #justdoit, #FridayFeelin...   16:22:19
# 22                       [#Discounts365days, #JustDoIt]   16:21:55
# 23                                   [#Justdoit, #Nike]   16:21:54
# 24                                         [#Justdoit!]   16:21:41
# 25                                      [#newyoutubers]   16:21:39
# 26                                          [#JustDoIt]   16:21:28
# 27      [#NikeStrong, #JustDoIt, #TeamNike, #ImWithKap]   16:21:25
# 28                            [#justdoit, #juststealit]   16:21:12
# 29      [#legday, #justdoit, #flexfriday, #berkhansays]   16:21:09
# ...                                                 ...        ...
# 5059                                        [#Justdoit]   00:21:21
# 5060                                       [#Rawkngrub]   00:21:21
# 5061       [#BookRecommendations, #JustDoIt, #WeAreOne]   00:21:12
# 5062  [#kermitgetsfit, #tireflips, #crossfit, #wod, ...   00:21:00
# 5063                              [#JustDoIt, #BringIt]   00:20:36
# 5064                                        [#justdoit]   00:20:36
# 5065                                        [#JustDoIt]   00:20:07
# 5066                                        [#JustDoIt]   00:20:06
# 5067        [#JustDoIt, #WalkAway, #MoveOnToGab, #ccot]   00:20:04
# 5068  [#HisRoadTrip, #Travel, #GreatBook, #BestSelle...   00:20:02
# 5069                 [#Mrhoffaatme, #MrBall, #Justdoit]   00:20:02
# 5070           [#FortyFive, #NotMyPresident, #JustDoIt]   00:20:01
# 5071                                        [#justdoit]   00:19:55
# 5072                                        [#JustDoIt]   00:19:47
# 5073  [#dontburnyourshoes, #boxing, #boxingbootcamp,...   00:19:44
# 5074                                        [#JustDoIt]   00:19:37
# 5075                                        [#JustDoIt]   00:19:33
# 5076  [#believeinsomething, #nike, #justdoit, #colin...   00:19:28
# 5077                                        [#justdoit]   00:19:15
# 5078                               [#UsOpen, #JustDoIt]   00:19:01
# 5079                                        [#JustDoIt]   00:18:53
# 5080  [#Houston, #HoustonRockets, #Rockets, #HTown, ...   00:18:43
# 5081                                        [#JustDoIt]   00:18:29
# 5082  [#juststringit, #believe, #sacrifice, #nike, #...   00:18:25
# 5083                             [#PHIvsATL, #JustDoIt]   00:18:25
# 5084                                        [#JustDoIt]   00:18:24
# 5085   [#RapDevil, #justdoit, #neverbackdown, #believe]   00:18:14
# 5086                  [#MamaSaidKnockYouOut, #JustDoIt]   00:18:05
# 5087                    [#USOpen2018, #Tutu, #JustDoIt]   00:17:49
# 5088                                        [#Justdoit]   00:17:13
#
#       tweet_date        tweet_user_id  \
# 0     2018-09-07           3188618684
# 1     2018-09-07             18387174
# 2     2018-09-07             32645612
# 3     2018-09-07            175932740
# 4     2018-09-07             22306628
# 5     2018-09-07             15566700
# 6     2018-09-07            174307749
# 7     2018-09-07   743856280717172737
# 8     2018-09-07             21149200
# 9     2018-09-07  1032243057746472960
# 10    2018-09-07            287412793
# 11    2018-09-07            538533358
# 12    2018-09-07            305589676
# 13    2018-09-07           2442615413
# 14    2018-09-07             42350706
# 15    2018-09-07            305589676
# 16    2018-09-07   795020884167770112
# 17    2018-09-07           1096452331
# 18    2018-09-07   981897559705780224
# 19    2018-09-07            462683900
# 20    2018-09-07           1511279516
# 21    2018-09-07             51053193
# 22    2018-09-07            804501012
# 23    2018-09-07            258403085
# 24    2018-09-07           2888891305
# 25    2018-09-07            411002863
# 26    2018-09-07             89155743
# 27    2018-09-07             34295011
# 28    2018-09-07            167540418
# 29    2018-09-07            105285304
# ...          ...                  ...
# 5059  2018-09-07             11391972
# 5060  2018-09-07            271644186
# 5061  2018-09-07   897496620169916416
# 5062  2018-09-07            506914758
# 5063  2018-09-07             70101580
# 5064  2018-09-07  1022654087861624832
# 5065  2018-09-07           1936605001
# 5066  2018-09-07           1343210436
# 5067  2018-09-07             56275127
# 5068  2018-09-07   810577073882468353
# 5069  2018-09-07   983642053199519744
# 5070  2018-09-07            113451238
# 5071  2018-09-07             37323921
# 5072  2018-09-07           3156919382
# 5073  2018-09-07             37728562
# 5074  2018-09-07            115983717
# 5075  2018-09-07            354992778
# 5076  2018-09-07            475211280
# 5077  2018-09-07            265534179
# 5078  2018-09-07            243502692
# 5079  2018-09-07             23797371
# 5080  2018-09-07             62734932
# 5081  2018-09-07             47207414
# 5082  2018-09-07           2842070309
# 5083  2018-09-07            431106722
# 5084  2018-09-07             17514726
# 5085  2018-09-07   798157472263446532
# 5086  2018-09-07             16634486
# 5087  2018-09-07            126147359
# 5088  2018-09-07             28454708
#
#                                   tweet_source_url  popular_hashtag_flag
# 0                           https://statusbrew.com                     1
# 1                  http://www.facebook.com/twitter                     1
# 2               http://twitter.com/download/iphone                     0
# 3                             http://instagram.com                     0
# 4                               http://twitter.com                     0
# 5               http://twitter.com/download/iphone                     0
# 6                               http://twitter.com                     0
# 7               http://twitter.com/download/iphone                     0
# 8                               http://twitter.com                     0
# 9              http://twitter.com/download/android                     0
# 10              http://twitter.com/download/iphone                     0
# 11                              http://twitter.com                     0
# 12                      https://mobile.twitter.com                     0
# 13              http://twitter.com/download/iphone                     0
# 14              http://twitter.com/download/iphone                     0
# 15                      https://mobile.twitter.com                     0
# 16                        http://www.linkedin.com/                     0
# 17             http://twitter.com/download/android                     0
# 18              http://twitter.com/download/iphone                     0
# 19             http://twitter.com/download/android                     0
# 20              http://twitter.com/download/iphone                     0
# 21              http://twitter.com/download/iphone                     1
# 22                              http://twitter.com                     0
# 23                            http://instagram.com                     0
# 24                 http://www.facebook.com/twitter                     0
# 25                      https://mobile.twitter.com                     0
# 26                              http://twitter.com                     0
# 27              http://twitter.com/download/iphone                     0
# 28                              http://twitter.com                     0
# 29                            http://instagram.com                     0
# ...                                            ...                   ...
# 5059                            http://twitter.com                     0
# 5060            http://twitter.com/download/iphone                     0
# 5061            http://twitter.com/download/iphone                     0
# 5062                          http://instagram.com                     6
# 5063            http://twitter.com/download/iphone                     0
# 5064            http://twitter.com/download/iphone                     0
# 5065            http://twitter.com/download/iphone                     0
# 5066            http://twitter.com/download/iphone                     0
# 5067                          http://janetter.net/                     0
# 5068                            https://buffer.com                     0
# 5069           http://twitter.com/download/android                     0
# 5070           http://twitter.com/download/android                     0
# 5071            http://twitter.com/download/iphone                     0
# 5072            http://twitter.com/download/iphone                     0
# 5073                          http://instagram.com                     1
# 5074                            http://twitter.com                     0
# 5075            http://twitter.com/download/iphone                     0
# 5076                          http://instagram.com                     1
# 5077                          http://instagram.com                     0
# 5078           http://twitter.com/download/android                     0
# 5079                            http://twitter.com                     0
# 5080           http://twitter.com/download/android                     0
# 5081           http://twitter.com/download/android                     0
# 5082           http://twitter.com/download/android                     1
# 5083            http://twitter.com/download/iphone                     0
# 5084           http://twitter.com/download/android                     0
# 5085           http://twitter.com/download/android                     0
# 5086  https://about.twitter.com/products/tweetdeck                     0
# 5087            http://twitter.com/download/iphone                     0
# 5088            http://twitter.com/download/iphone                     0
#
# [5089 rows x 20 columns]

# %%
#Final Databases:
# 1. User data set: user_data
# 2. Tweet data with popular_hashtag_flag: tweet_data
